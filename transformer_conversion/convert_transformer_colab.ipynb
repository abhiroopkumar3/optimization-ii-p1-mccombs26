# %% [markdown]
# # Step-by-step Colab workflow to convert:
# `connect4_transformer_best.keras` → `connect4_transformer_best.h5`

# %% [markdown]
# **Step 1) Open a new Colab notebook**
# Go to Colab → New Notebook
#
# **Step 2) Upload the 2 files Colab needs**
# On the left sidebar in Colab:
# - Click the folder icon (📁)
# - Click Upload to session
# - Upload these two files from the computer:
#     - `connect4_transformer_best.keras`
#     - `connect4.py`
#
# ✅ **They should appear in /content/**

# %% [markdown]
# 1. Required Imports

# %%
# !pip -q install -U "tensorflow==2.19.0" "keras==3.6.0" "protobuf>=5.26.1,<6"
# !pip -q install pandas

# %% [markdown]
# > *Restart **Runtime** in Google Colab*

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
print("TF:", tf.__version__)
print("Keras:", keras.__version__)
print("NumPy:", np.__version__)
# Out:
# TF: 2.19.0
# Keras: 3.6.0
# NumPy: 1.26.4

# %% [markdown]
# 2. Import Custom Layers

# %%
from connect4 import FixedSubblockExtractor, AdditivePositionalEncoding, ClassToken, TransformerEncoder

# %% [markdown]
# 3. Convert

# %%
from tensorflow import keras

src = "/content/connect4_transformer_best.keras"
dst = "/content/connect4_transformer_best.h5"

model = keras.models.load_model(
    src,
    custom_objects={
        "FixedSubblockExtractor": FixedSubblockExtractor,
        "AdditivePositionalEncoding": AdditivePositionalEncoding,
        "ClassToken": ClassToken,
        "TransformerEncoder": TransformerEncoder,
    },
    compile=False
)

model.save(dst)
print("✅ Saved:", dst)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Saved: /content/connect4_transformer_best.h5

# %% [markdown]
# 5. Download

# %%
from google.colab import files
files.download(dst)

# %% [markdown]
# # Clean Fix: Export Transformer as TF 2.9 “SavedModel”, then load it in TF 2.9

# %% [markdown]
# 1. In Colab: Load and export to SavedModel

# %%
import tensorflow as tf
from tensorflow import keras

from connect4 import FixedSubblockExtractor, AdditivePositionalEncoding, ClassToken, TransformerEncoder

src = "/content/connect4_transformer_best.keras"
model = keras.models.load_model(
    src,
    custom_objects={
        "FixedSubblockExtractor": FixedSubblockExtractor,
        "AdditivePositionalEncoding": AdditivePositionalEncoding,
        "ClassToken": ClassToken,
        "TransformerEncoder": TransformerEncoder,
    },
    compile=False
)
print("Loaded")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_1', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_2', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/layer.py:391: UserWarning: `build()` was called on layer 'transformer_encoder_3', however the layer does not have a `build()` method implemented and it looks like it has unbuilt state. This will cause the layer to be marked as built, despite not being actually built, which may cause failures down the line. Make sure to implement a proper `build()` method.
#   warnings.warn(
# Loaded

# %% [markdown]
# 2. Export using model.export()

# %%
export_dir = "/content/tx_savedmodel"
model.export(export_dir)
print("✅ Exported to", export_dir)
# Out:
# Saved artifact at '/content/tx_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 6, 7, 2), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 7), dtype=tf.float32, name=None)
# Captures:
#   137657920052240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920046864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920053776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920060304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920058960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875894672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875894288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875896208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875896016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875896592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875895056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137659739584656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875895248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875897744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875894864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875897360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875897552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875898320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875898128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875903120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875902928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875903504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875902160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875903888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875904656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875901200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875904272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875904464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875905232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657875905040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874843408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874843024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874842640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874843216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874844752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874844560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874845136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874843792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874845520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874843600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874846288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874842832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874845904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874846096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874846864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874846672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920056656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874849168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874849360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874848784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874850896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874850704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874851280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874849936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874851664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874849744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874852432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874849552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874852048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874852240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874853008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657874852816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920058576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920057808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920057616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920059728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920059920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137657920060496: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ✅ Exported to /content/tx_savedmodel

# %% [markdown]
# 3. Zip + download

# %%
# !zip -r /content/tx_savedmodel.zip /content/tx_savedmodel
from google.colab import files
files.download("/content/tx_savedmodel.zip")
# Out:
#   adding: content/tx_savedmodel/ (stored 0%)
#   adding: content/tx_savedmodel/fingerprint.pb (stored 0%)
#   adding: content/tx_savedmodel/variables/ (stored 0%)
#   adding: content/tx_savedmodel/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: content/tx_savedmodel/variables/variables.index (deflated 76%)
#   adding: content/tx_savedmodel/assets/ (stored 0%)
#   adding: content/tx_savedmodel/saved_model.pb (deflated 90%)
